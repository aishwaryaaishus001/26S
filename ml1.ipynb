# %% [markdown]
# <a href="https://colab.research.google.com/github/aishwaryaaishus001/26S/blob/main/ml1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random
import datetime

# %%
num_records = 30
dates = pd.date_range(start='2022-01-01', end='2022-12-31', periods = num_records)
prices = [round(random.uniform(10, 100), 2) for _ in range(num_records)]
product_ids = [random.randint(1, 100) for _ in range(num_records)]
quantities = [random.randint(1, 10) for _ in range(num_records)]
serial_nos = [f'SN-{random.randint(1000, 9999)}' for _ in range(num_records)]
user_ids = ['U' + str(random.randint(10, 20)) for _ in range(num_records)]
user_types = ['Retail', 'Wholesale']
user_classes = ['Class A', 'Class B', 'Class C']
purchase_weeks = [date.isocalendar()[1] for date in dates]

data = {
    'Date' : dates,
    'Price' : prices,
    'Product_Id' : product_ids,
    'Quantity_Purchased' : quantities,
    'Serial_No' : serial_nos,
    'User_Id' : user_ids,
    'User_Type' : random.choices(user_types, k=num_records),
    'User_Class' : random.choices(user_classes, k=num_records),
    'Purchase_Week' : purchase_weeks
}

df = pd.DataFrame(data)

print(df.head())

df.to_csv('customer_dataset.csv', index=False)
# Out:
#                            Date  Price  Product_Id  Quantity_Purchased  \
# 0 2022-01-01 00:00:00.000000000  54.67          46                   2
# 1 2022-01-13 13:14:28.965517241  87.37         100                   6
# 2 2022-01-26 02:28:57.931034482  34.75          90                   7
# 3 2022-02-07 15:43:26.896551724  68.24          31                   7
# 4 2022-02-20 04:57:55.862068965  18.23          22                   1
#
#   Serial_No User_Id  User_Type User_Class  Purchase_Week
# 0   SN-4901     U14  Wholesale    Class C             52
# 1   SN-5708     U16  Wholesale    Class B              2
# 2   SN-6280     U15  Wholesale    Class C              4
# 3   SN-6419     U15  Wholesale    Class C              6
# 4   SN-8275     U20  Wholesale    Class B              7

# %%
import matplotlib.pyplot as plt

df = pd.read_csv('customer_dataset.csv')
user_id = 'U15'
user_data = df[df['User_Id'] == user_id]

plt.figure(figsize=(10, 6))
plt.plot(user_data['Date'], user_data['Price'], alpha = 0.5)
plt.xlabel = ('Date')
plt.ylabel = ('Price')
plt.xticks(rotation=45)
plt.title('Price Trends For User {user_id}')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Date'], df['Price'], alpha = 0.5)
plt.scatter(user_data['Date'], user_data['Price'], color='red', label=f'User_Id {user_id}')
plt.xlabel = ('Date')
plt.ylabel = ('Price')
plt.xticks(rotation=45)
plt.title('Price Trends For User {user_id} Over Time')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['Quantity_Purchased'])
plt.xlabel = ('Quantity_Purchased')
plt.title('Distribution of Quantity Purchased')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(df['Purchase_Week'])
plt.xlabel = ('Purchase_Week')
plt.title('Distribution of Purchase Week')
plt.show()
